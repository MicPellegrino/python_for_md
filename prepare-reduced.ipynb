# %%
import numpy as np
import mdconf_oop as md

# %%
T_RED_FAC = 120.27236

# %%
# %cd /home/michele/python_for_md/ViscosityReduced
# Out:
# /home/michele/python_for_md/ViscosityReduced

# %%
# %ls
# Out:
# init.gro  lj.itp  topology.top

# %%
lj_conf = md.Configuration(Lx=12, Ly=12, Lz=12)
# Out:
# Initializing an empty simulation box

# %%
lj_conf.lj_wall(0, nk=10, sp=1.224744871391589, resname='PT1', cut_box=True)

# %%
lj_conf.print_info()
# Out:
# ### MDCONF ###
#
# no. atoms = 1080
# Lx = 11.022703842524301
# Ly = 12.727922061357855
# Lz = 12
# Res: PT1, #molecules = 1080, atom types {'CUB'}
# ##############

# %%
lj_conf.output('init.gro')
# Out:
# Writing .gro configuration file

# %%
L = (1080/0.452)**(1/3)
print(L)
# Out:
# 13.368882519382403

# %%
T = 2*T_RED_FAC
print(T)
# Out:
# 240.54472

# %%
(10**5)/0.01
# Out:
# 10000000.0
