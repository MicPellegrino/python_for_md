# %%
import mdconf_oop as md
import produce_grafted_substrate as pgs

# %%
# %cd /home/michele/python_for_md/GraftedSilica/TestGrafing
# Out:
# /home/michele/python_for_md/GraftedSilica/TestGrafing

# %%
gs = md.Configuration(Lx=5,Ly=4.8,Lz=5)
# Out:
# Initializing an empty simulation box

# %%
gs.silica_monolayer_grafted(z_wall=1.0,dens=3,n_chain=18)
# Out:
# Grafting 72 quadrupoles out of 132
# [ 23  82  76  83  97 128 104  90 110   6   3  37 116  58  11  42   5 131
#  111  29  77  15 114   1 100 113   2  48 102  68  59  86  17 115 118  21
#   43  67  99  32  49  39  70  47  35 103 130  36  66  98  87 122  44 127
#  101 129  54  41  89 125  46 108   0  74 106  79  69  13  62  34  73  19]

# %%
print(sorted(gs.res_nomicon['GRA']))
# Out:
# ['C', 'CS', 'H1', 'H2', 'H3', 'O2', 'SI']

# %%
# gs.remove_residue('SUB')
# gs.remove_residue('GRA')

# %%
gs.output('test1.gro')
# Out:
# Writing .gro configuration file

# %%
gs.print_info()
# Out:
# ### MDCONF ###
#
# no. atoms = 4140
# Lx = 5
# Ly = 4.8
# Lz = 5
# Res: SUB, #molecules = 60, atom types {'O2', 'SI', 'O1'}
# Res: GRA, #molecules = 565, atom types {'H1', 'H2', 'O2', 'SI', 'C', 'CS', 'H3'}
# ##############

# %%
# pgs.grafting_chain(n_chain=18)
