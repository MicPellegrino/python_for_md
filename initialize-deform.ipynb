# %%
# %cd /home/michele/python_for_md/TestDeform
# %ls
# Out:
# /home/michele/python_for_md/TestDeform
# Butanol/  empty0.gro  MixWb/            WaterGlycerol40/  WaterSPCE/
# Chexane/  MixBw/      WaterGlycerol20/  WaterGlycerol60/  WaterTIP4/

# %%
# Go to the desi directory
# %cd MixWb
# Out:
# /home/michele/python_for_md/TestDeform/MixWb

# %%
Nb = 116
Nw = 7799

# %%
import os
os.system("gmx insert-molecules -f ../empty0.gro -ci butanol-1.gro -nmol "+str(Nb)+" -o temp.gro")
os.system("gmx insert-molecules -f temp.gro -ci spce_molecule.gro -nmol "+str(Nw)+" -o init-conf.gro")
# os.system("gmx insert-molecules -f ../empty0.gro -ci spce_molecule.gro -nmol "+str(Nw)+" -o temp.gro")
# os.system("gmx insert-molecules -f temp.gro -ci butanol-1.gro -nmol "+str(Nb)+" -o init-conf.gro")
# os.system("gmx insert-molecules -f init-conf.gro -ci butanol-1.gro -nmol "+str(Nb)+" -o init-conf.gro -try 10000")
# Out:
# 0
