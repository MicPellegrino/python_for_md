# %%
import mdconf_oop as md

# %%
# %cd /home/michele/python_for_md/Glycerol80p/SmallMeniscus
# %ls
# Out:
# /home/michele/python_for_md/Glycerol80p/SmallMeniscus
#  empty.gro     solv-gly.gro     '#solv-glywat.gro.1#'
#  lambda0.gro   solv-glywat.gro

# %%
c = md.Configuration()
# Out:
# Initializing an empty simulation box

# %%
c.input('lambda0.gro')
# Out:
# Reading .gro configuration file

# %%
d = md.Configuration()
# Out:
# Initializing an empty simulation box

# %%
d.input('solv-glywat.gro')
# Out:
# Reading .gro configuration file

# %%
c.merge(d)

# %%
c.print_info()
# Out:
# ### MDCONF ###
#
# no. atoms = 66438
# Lx = 29.7
# Ly = 4.67654
# Lz = 10.0
# Res: SUB, #molecules = 1584, atom types {'SI', 'O1', 'O2'}
# Res: GOL, #molecules = 16142, atom types {'O', 'H', 'C'}
# Res: SOL, #molecules = 4420, atom types {'OW', 'HW2', 'HW1'}
# ##############

# %%
c.output('init-conf.gro')
# Out:
# Writing .gro configuration file

# %%
(66438-3*(1584+4420))/14
# Out:
# 3459.0
